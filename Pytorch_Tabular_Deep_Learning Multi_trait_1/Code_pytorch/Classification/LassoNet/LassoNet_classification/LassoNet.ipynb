# %%
# %pip install bayesian-optimization omegaconf

# %%
from google.colab import drive
import os
drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/Colab Notebooks/lassonet_bo')
# Out:
# Mounted at /content/drive

# %%
# %run entry.py
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /content/drive/MyDrive/Colab Notebooks/lassonet_bo/entry.py in <module>
#       2 ds_file = 'wheat-hitopt.csv'
#       3
# ----> 4 from data import load_wheat_csv_ds
#       5 from bo import bo_search
#       6
#
# ImportError: cannot import name 'load_wheat_csv_ds' from 'data' (/content/drive/MyDrive/Colab Notebooks/lassonet_bo/data.py)
